# %%
import warnings
warnings.filterwarnings('ignore')

# Mount Drive
from google.colab import drive
drive.mount('/content/drive')

# Setup Kaggle
# !mkdir -p ~/.kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# Download dataset
# !kaggle datasets download -d msambare/fer2013
# !unzip -q fer2013.zip -d /content/data

# Verify
# !ls /content/data
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Dataset URL: https://www.kaggle.com/datasets/msambare/fer2013
# License(s): DbCL-1.0
# Downloading fer2013.zip to /content
#   0% 0.00/60.3M [00:00<?, ?B/s]
# 100% 60.3M/60.3M [00:00<00:00, 1.69GB/s]
# test  train

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Create train (80%) and validation (20%) from train folder
train_datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2,
    rotation_range=15,
    width_shift_range=0.1,
    height_shift_range=0.1,
    horizontal_flip=True,
    zoom_range=0.1
)

train_generator = train_datagen.flow_from_directory(
    '/content/data/train',
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale',
    subset='training'
)

val_generator = train_datagen.flow_from_directory(
    '/content/data/train',
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale',
    subset='validation'
)

# Test data (separate folder, no split needed)
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_directory(
    '/content/data/test',
    target_size=(48, 48),
    batch_size=32,
    class_mode='categorical',
    color_mode='grayscale'
)

# Check labels
print(train_generator.class_indices)
# Out:
# Found 22968 images belonging to 7 classes.
# Found 5741 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.
# {'angry': 0, 'disgust': 1, 'fear': 2, 'happy': 3, 'neutral': 4, 'sad': 5, 'surprise': 6}

# %%
# Get one batch
images, labels = next(train_generator)
# Check shapes
print("Batch of images:", images.shape)   # (32, 48, 48, 3)
print("Batch of labels:", labels.shape)   # (32, 7)
# Out:
# Batch of images: (32, 48, 48, 1)
# Batch of labels: (32, 7)

# %%
from keras.models import Sequential
from keras.layers import Input, Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization

# %%
model = Sequential([
    Input(shape=(48, 48, 1)),

    Conv2D(64, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(128, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Conv2D(256, (3, 3), activation='relu', padding='same'),
    BatchNormalization(),
    MaxPooling2D((2, 2)),
    Dropout(0.25),

    Flatten(),
    Dense(256, activation='relu'),
    BatchNormalization(),
    Dropout(0.5),
    Dense(7, activation='softmax')
])

# %%
model.summary()
# Out:
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d_9 (Conv2D)               │ (None, 48, 48, 64)     │           640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_12          │ (None, 48, 48, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_9 (MaxPooling2D)  │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_12 (Dropout)            │ (None, 24, 24, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_10 (Conv2D)              │ (None, 24, 24, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_13          │ (None, 24, 24, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_10 (MaxPooling2D) │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_13 (Dropout)            │ (None, 12, 12, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_11 (Conv2D)              │ (None, 12, 12, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_14          │ (None, 12, 12, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_11 (MaxPooling2D) │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_14 (Dropout)            │ (None, 6, 6, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_3 (Flatten)             │ (None, 9216)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │     2,359,552 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_15          │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_15 (Dropout)            │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 7)              │         1,799 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 2,733,831 (10.43 MB)
#  Trainable params: 2,732,423 (10.42 MB)
#  Non-trainable params: 1,408 (5.50 KB)

# %%
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

history = model.fit(
    train_generator,
    validation_data=val_generator,
    epochs=50,
    callbacks=[
        EarlyStopping(patience=10, restore_best_weights=True),
        ModelCheckpoint('best_model.keras', save_best_only=True),
        ReduceLROnPlateau(factor=0.5, patience=5, verbose=1)
    ]
)
# Out:
# Epoch 1/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 40s 44ms/step - accuracy: 0.2242 - loss: 2.3056 - val_accuracy: 0.2831 - val_loss: 1.8092 - learning_rate: 0.0010
# Epoch 2/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.3361 - loss: 1.7080 - val_accuracy: 0.3057 - val_loss: 1.9294 - learning_rate: 0.0010
# Epoch 3/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - accuracy: 0.4062 - loss: 1.5340 - val_accuracy: 0.4034 - val_loss: 1.5374 - learning_rate: 0.0010
# Epoch 4/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.4368 - loss: 1.4647 - val_accuracy: 0.4250 - val_loss: 1.4730 - learning_rate: 0.0010
# Epoch 5/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.4614 - loss: 1.4175 - val_accuracy: 0.4499 - val_loss: 1.9602 - learning_rate: 0.0010
# Epoch 6/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.4749 - loss: 1.3819 - val_accuracy: 0.4635 - val_loss: 1.4798 - learning_rate: 0.0010
# Epoch 7/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.4850 - loss: 1.3528 - val_accuracy: 0.3607 - val_loss: 1.6401 - learning_rate: 0.0010
# Epoch 8/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.4699 - loss: 1.3762 - val_accuracy: 0.4562 - val_loss: 1.4247 - learning_rate: 0.0010
# Epoch 9/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.4679 - loss: 1.3955 - val_accuracy: 0.4766 - val_loss: 1.4416 - learning_rate: 0.0010
# Epoch 10/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 26s 36ms/step - accuracy: 0.5005 - loss: 1.3024 - val_accuracy: 0.4585 - val_loss: 1.4086 - learning_rate: 0.0010
# Epoch 11/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5069 - loss: 1.2876 - val_accuracy: 0.4048 - val_loss: 1.6643 - learning_rate: 0.0010
# Epoch 12/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5053 - loss: 1.3198 - val_accuracy: 0.4870 - val_loss: 1.5159 - learning_rate: 0.0010
# Epoch 13/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5246 - loss: 1.2545 - val_accuracy: 0.5341 - val_loss: 1.2221 - learning_rate: 0.0010
# Epoch 14/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - accuracy: 0.5250 - loss: 1.2351 - val_accuracy: 0.5036 - val_loss: 1.4004 - learning_rate: 0.0010
# Epoch 15/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 23s 33ms/step - accuracy: 0.5213 - loss: 1.2552 - val_accuracy: 0.5104 - val_loss: 1.2727 - learning_rate: 0.0010
# Epoch 16/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5293 - loss: 1.2385 - val_accuracy: 0.5287 - val_loss: 1.2468 - learning_rate: 0.0010
# Epoch 17/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5358 - loss: 1.2282 - val_accuracy: 0.5414 - val_loss: 1.2281 - learning_rate: 0.0010
# Epoch 18/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.5339 - loss: 1.2219 - val_accuracy: 0.5367 - val_loss: 1.2193 - learning_rate: 0.0010
# Epoch 19/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.5378 - loss: 1.2182 - val_accuracy: 0.5421 - val_loss: 1.2176 - learning_rate: 0.0010
# Epoch 20/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5416 - loss: 1.2058 - val_accuracy: 0.5523 - val_loss: 1.1822 - learning_rate: 0.0010
# Epoch 21/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5489 - loss: 1.1940 - val_accuracy: 0.5560 - val_loss: 1.1843 - learning_rate: 0.0010
# Epoch 22/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5560 - loss: 1.1844 - val_accuracy: 0.4531 - val_loss: 1.5394 - learning_rate: 0.0010
# Epoch 23/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5531 - loss: 1.1883 - val_accuracy: 0.5356 - val_loss: 1.2234 - learning_rate: 0.0010
# Epoch 24/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.5634 - loss: 1.1646 - val_accuracy: 0.5574 - val_loss: 1.1875 - learning_rate: 0.0010
# Epoch 25/50
# 716/718 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.5608 - loss: 1.1562
# Epoch 25: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - accuracy: 0.5608 - loss: 1.1562 - val_accuracy: 0.5563 - val_loss: 1.1856 - learning_rate: 0.0010
# Epoch 26/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5662 - loss: 1.1501 - val_accuracy: 0.5541 - val_loss: 1.1622 - learning_rate: 5.0000e-04
# Epoch 27/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5731 - loss: 1.1326 - val_accuracy: 0.5609 - val_loss: 1.1506 - learning_rate: 5.0000e-04
# Epoch 28/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.5798 - loss: 1.1097 - val_accuracy: 0.5839 - val_loss: 1.1103 - learning_rate: 5.0000e-04
# Epoch 29/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5832 - loss: 1.1030 - val_accuracy: 0.5534 - val_loss: 1.2129 - learning_rate: 5.0000e-04
# Epoch 30/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - accuracy: 0.5859 - loss: 1.1007 - val_accuracy: 0.5732 - val_loss: 1.1162 - learning_rate: 5.0000e-04
# Epoch 31/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.5912 - loss: 1.0888 - val_accuracy: 0.5781 - val_loss: 1.1261 - learning_rate: 5.0000e-04
# Epoch 32/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - accuracy: 0.5939 - loss: 1.0790 - val_accuracy: 0.5349 - val_loss: 1.2408 - learning_rate: 5.0000e-04
# Epoch 33/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.5954 - loss: 1.0920 - val_accuracy: 0.5887 - val_loss: 1.0987 - learning_rate: 5.0000e-04
# Epoch 34/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.5878 - loss: 1.0867 - val_accuracy: 0.5555 - val_loss: 1.2175 - learning_rate: 5.0000e-04
# Epoch 35/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.5936 - loss: 1.0883 - val_accuracy: 0.5360 - val_loss: 1.2663 - learning_rate: 5.0000e-04
# Epoch 36/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.5885 - loss: 1.0847 - val_accuracy: 0.5832 - val_loss: 1.1134 - learning_rate: 5.0000e-04
# Epoch 37/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - accuracy: 0.5908 - loss: 1.0818 - val_accuracy: 0.5874 - val_loss: 1.0980 - learning_rate: 5.0000e-04
# Epoch 38/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.5941 - loss: 1.0664 - val_accuracy: 0.5814 - val_loss: 1.1172 - learning_rate: 5.0000e-04
# Epoch 39/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - accuracy: 0.6036 - loss: 1.0634 - val_accuracy: 0.5990 - val_loss: 1.0781 - learning_rate: 5.0000e-04
# Epoch 40/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 25s 35ms/step - accuracy: 0.5953 - loss: 1.0757 - val_accuracy: 0.5957 - val_loss: 1.0605 - learning_rate: 5.0000e-04
# Epoch 41/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 25s 34ms/step - accuracy: 0.6001 - loss: 1.0617 - val_accuracy: 0.5860 - val_loss: 1.1044 - learning_rate: 5.0000e-04
# Epoch 42/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - accuracy: 0.5969 - loss: 1.0644 - val_accuracy: 0.5555 - val_loss: 1.1898 - learning_rate: 5.0000e-04
# Epoch 43/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.6032 - loss: 1.0485 - val_accuracy: 0.5382 - val_loss: 1.2506 - learning_rate: 5.0000e-04
# Epoch 44/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.6064 - loss: 1.0569 - val_accuracy: 0.6027 - val_loss: 1.0621 - learning_rate: 5.0000e-04
# Epoch 45/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.6022 - loss: 1.0542
# Epoch 45: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.6022 - loss: 1.0542 - val_accuracy: 0.5874 - val_loss: 1.0905 - learning_rate: 5.0000e-04
# Epoch 46/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.6089 - loss: 1.0428 - val_accuracy: 0.5989 - val_loss: 1.0690 - learning_rate: 2.5000e-04
# Epoch 47/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.6178 - loss: 1.0302 - val_accuracy: 0.6051 - val_loss: 1.0477 - learning_rate: 2.5000e-04
# Epoch 48/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.6165 - loss: 1.0125 - val_accuracy: 0.6039 - val_loss: 1.0562 - learning_rate: 2.5000e-04
# Epoch 49/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 34ms/step - accuracy: 0.6218 - loss: 1.0134 - val_accuracy: 0.5546 - val_loss: 1.2474 - learning_rate: 2.5000e-04
# Epoch 50/50
# 718/718 ━━━━━━━━━━━━━━━━━━━━ 24s 33ms/step - accuracy: 0.6120 - loss: 1.0232 - val_accuracy: 0.5853 - val_loss: 1.1039 - learning_rate: 2.5000e-04

# %%
test_loss, test_accuracy = model.evaluate(test_generator)
print(f"Test Accuracy: {test_accuracy * 100:.2f}%")
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 4s 16ms/step - accuracy: 0.6228 - loss: 1.0207
# Test Accuracy: 62.87%

# %%
from google.colab import files
files.download('best_model.keras')
